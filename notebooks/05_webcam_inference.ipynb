# %% [markdown]
# # Webcam Inference Walkthrough
# Use `run_webcam.py` from project root for real-time inference.

# %%
# Example command (run in terminal):
# python run_webcam.py --model-path models/asl_mobilenetv2.keras --class-names models/class_names.json --camera-index 0
